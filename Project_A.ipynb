# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('FinalProjectData/Study_A.csv')
df = df[df['LeadStatus'] != 'Flagged']

# %%
df[df['TxGroup'] == 'Control']
# Out:
#      Study Country  PatientID  SiteID  RaterID  AssessmentID  TxGroup  \
# 0        A     USA      10001   20035    30076        100679  Control
# 1        A     USA      10001   20035    30076        101017  Control
# 2        A     USA      10001   20035    30076        102177  Control
# 7        A     USA      10002   20011    30016        100597  Control
# 8        A     USA      10002   20011    30016        100270  Control
# ...    ...     ...        ...     ...      ...           ...      ...
# 2390     A     USA      10350   20029    30018        101363  Control
# 2391     A     USA      10350   20029    30018        101513  Control
# 2392     A     USA      10350   20029    30018        100709  Control
# 2393     A     USA      10350   20029    30018        102022  Control
# 2395     A     USA      10350   20029    30018        101744  Control
#
#       VisitDay  P1  P2  ...  G9  G10  G11  G12  G13  G14  G15  G16  \
# 0            0   5   5  ...   5    3    3    4    3    3    3    5
# 1           11   5   5  ...   5    3    3    4    3    3    3    5
# 2           18   4   4  ...   4    2    2    3    3    2    3    4
# 7            0   5   5  ...   5    2    1    3    3    3    3    5
# 8            7   5   5  ...   5    3    1    3    3    1    3    5
# ...        ...  ..  ..  ...  ..  ...  ...  ...  ...  ...  ...  ...
# 2390        20   5   3  ...   4    1    3    3    2    2    4    3
# 2391        34   4   3  ...   5    1    3    3    1    1    3    3
# 2392        49   4   3  ...   4    1    2    2    2    1    3    3
# 2393        61   4   3  ...   4    1    1    2    2    1    3    3
# 2395        89   4   3  ...   4    1    2    1    1    1    3    2
#
#       PANSS_Total    LeadStatus
# 0             107  Assign to CS
# 1             109  Assign to CS
# 2              91        Passed
# 7              85        Passed
# 8              85        Passed
# ...           ...           ...
# 2390           76        Passed
# 2391           70        Passed
# 2392           69        Passed
# 2393           67        Passed
# 2395           64        Passed
#
# [894 rows x 40 columns]

# %%
df[df['TxGroup'] == 'Treatment']
# Out:
#      Study Country  PatientID  SiteID  RaterID  AssessmentID    TxGroup  \
# 33       A     USA      10006   20009    30028        101069  Treatment
# 34       A     USA      10006   20009    30028        100526  Treatment
# 37       A     USA      10006   20009    30028        102087  Treatment
# 38       A     USA      10006   20009    30026        101414  Treatment
# 39       A     USA      10006   20009    30026        101426  Treatment
# ...    ...     ...        ...     ...      ...           ...        ...
# 2398     A     USA      10351   20004    30039        101959  Treatment
# 2399     A     USA      10351   20004    30039        101215  Treatment
# 2400     A     USA      10351   20004    30039        100903  Treatment
# 2401     A     USA      10351   20004    30039        101955  Treatment
# 2402     A     USA      10351   20004    30068        100700  Treatment
#
#       VisitDay  P1  P2  ...  G9  G10  G11  G12  G13  G14  G15  G16  \
# 33           0   5   5  ...   6    2    3    3    4    3    5    4
# 34          10   5   5  ...   6    1    3    4    4    3    5    4
# 37          38   3   1  ...   3    1    2    2    2    2    2    3
# 38          50   3   1  ...   3    1    2    2    2    2    2    4
# 39          67   3   1  ...   1    1    1    1    1    1    1    3
# ...        ...  ..  ..  ...  ..  ...  ...  ...  ...  ...  ...  ...
# 2398        16   5   4  ...   4    2    3    3    3    3    4    4
# 2399        23   5   4  ...   5    1    3    3    3    3    4    4
# 2400        37   5   4  ...   5    1    3    3    3    3    4    3
# 2401        51   5   4  ...   5    1    3    3    3    3    4    3
# 2402        53   5   6  ...   5    2    4    4    3    4    5    5
#
#       PANSS_Total  LeadStatus
# 33            110      Passed
# 34            108      Passed
# 37             59      Passed
# 38             62      Passed
# 39             47      Passed
# ...           ...         ...
# 2398           81      Passed
# 2399           84      Passed
# 2400           84      Passed
# 2401           83      Passed
# 2402          112      Passed
#
# [837 rows x 40 columns]

# %%
df[df['PatientID'] == 10351]
# Out:
#      Study Country  PatientID  SiteID  RaterID  AssessmentID    TxGroup  \
# 2396     A     USA      10351   20004    30039        101501  Treatment
# 2397     A     USA      10351   20004    30039        101531  Treatment
# 2398     A     USA      10351   20004    30039        101959  Treatment
# 2399     A     USA      10351   20004    30039        101215  Treatment
# 2400     A     USA      10351   20004    30039        100903  Treatment
# 2401     A     USA      10351   20004    30039        101955  Treatment
# 2402     A     USA      10351   20004    30068        100700  Treatment
#
#       VisitDay  P1  P2  ...  G9  G10  G11  G12  G13  G14  G15  G16  \
# 2396         0   5   5  ...   5    2    3    3    3    2    4    4
# 2397         9   5   5  ...   5    2    3    3    3    3    4    4
# 2398        16   5   4  ...   4    2    3    3    3    3    4    4
# 2399        23   5   4  ...   5    1    3    3    3    3    4    4
# 2400        37   5   4  ...   5    1    3    3    3    3    4    3
# 2401        51   5   4  ...   5    1    3    3    3    3    4    3
# 2402        53   5   6  ...   5    2    4    4    3    4    5    5
#
#       PANSS_Total  LeadStatus
# 2396           93      Passed
# 2397           90      Passed
# 2398           81      Passed
# 2399           84      Passed
# 2400           84      Passed
# 2401           83      Passed
# 2402          112      Passed
#
# [7 rows x 40 columns]

# %%
df_panss = df[['PatientID', 'VisitDay', 'PANSS_Total']][df['TxGroup'] == 'Treatment']

# %%
df_panss
# Out:
#       PatientID  VisitDay  PANSS_Total
# 33        10006         0          110
# 34        10006        10          108
# 37        10006        38           59
# 38        10006        50           62
# 39        10006        67           47
# ...         ...       ...          ...
# 2398      10351        16           81
# 2399      10351        23           84
# 2400      10351        37           84
# 2401      10351        51           83
# 2402      10351        53          112
#
# [837 rows x 3 columns]

# %%
# for every same patient, get the difference of PANSS_Total between the first and last visit 
# the result should be a dataframe with two columns: PatientID, PANSS_Total_Diff
df_panss_diff = pd.DataFrame(columns=['PatientID', 'PANSS_Total_Diff'])

for patient_id in df_panss['PatientID'].unique():
    patient_panss = df_panss[df_panss['PatientID'] == patient_id]
    patient_panss_diff = patient_panss.iloc[-1]['PANSS_Total'] - patient_panss.iloc[0]['PANSS_Total']
    df_panss_diff = df_panss_diff.append({'PatientID': patient_id, 'PANSS_Total_Diff': patient_panss_diff}, ignore_index=True)
    
df_panss_diff
# Out:
#     PatientID PANSS_Total_Diff
# 0       10006              -34
# 1       10009                3
# 2       10013              -32
# 3       10014              -10
# 4       10015                9
# ..        ...              ...
# 154     10345                0
# 155     10346              -26
# 156     10347              -26
# 157     10348              -24
# 158     10351               19
#
# [159 rows x 2 columns]

# %%
# if PANSS_Total_Diff > 0, then assign False to the new column 'Effective'
# if PANSS_Total_Diff <= 0, then assign True to the new column 'Effective'
df_panss_diff['Effective'] = df_panss_diff['PANSS_Total_Diff'] <= 0
df_panss_diff
# Out:
#     PatientID PANSS_Total_Diff  Effective
# 0       10006              -34       True
# 1       10009                3      False
# 2       10013              -32       True
# 3       10014              -10       True
# 4       10015                9      False
# ..        ...              ...        ...
# 154     10345                0       True
# 155     10346              -26       True
# 156     10347              -26       True
# 157     10348              -24       True
# 158     10351               19      False
#
# [159 rows x 3 columns]

# %%
print(df_panss_diff['Effective'].value_counts(), '\n')
print(df_panss_diff['Effective'].value_counts(normalize=True))
plt.bar(['Effective', 'Not Effective'], [len(df_panss_diff[df_panss_diff['Effective'] == True]), len(df_panss_diff[df_panss_diff['Effective'] == False])])
plt.title('Treatment Group')
# Out:
# True     118
# False     41
# Name: Effective, dtype: int64
#
# True     0.742138
# False    0.257862
# Name: Effective, dtype: float64
# Text(0.5, 1.0, 'Treatment Group')

# %%
df_panss_control = df[['PatientID', 'VisitDay', 'PANSS_Total']][df['TxGroup'] == 'Control']

df_panss_control_diff = pd.DataFrame(columns=['PatientID', 'PANSS_Total_Diff'])

for patient_id in df_panss_control['PatientID'].unique():
    patient_panss = df_panss_control[df_panss_control['PatientID'] == patient_id]
    patient_panss_diff = patient_panss.iloc[-1]['PANSS_Total'] - patient_panss.iloc[0]['PANSS_Total']
    df_panss_control_diff = df_panss_control_diff.append({'PatientID': patient_id, 'PANSS_Total_Diff': patient_panss_diff}, ignore_index=True)
    
df_panss_control_diff
# Out:
#     PatientID PANSS_Total_Diff
# 0       10001              -16
# 1       10002                9
# 2       10004              -30
# 3       10005              -40
# 4       10007               30
# ..        ...              ...
# 172     10335               -8
# 173     10338                0
# 174     10339              -15
# 175     10349              -44
# 176     10350              -31
#
# [177 rows x 2 columns]

# %%
df_panss_control_diff['Effective'] = df_panss_control_diff['PANSS_Total_Diff'] <= 0
df_panss_control_diff
# Out:
#     PatientID PANSS_Total_Diff  Effective
# 0       10001              -16       True
# 1       10002                9      False
# 2       10004              -30       True
# 3       10005              -40       True
# 4       10007               30      False
# ..        ...              ...        ...
# 172     10335               -8       True
# 173     10338                0       True
# 174     10339              -15       True
# 175     10349              -44       True
# 176     10350              -31       True
#
# [177 rows x 3 columns]

# %%
print(df_panss_control_diff['Effective'].value_counts(), '\n')
print(df_panss_control_diff['Effective'].value_counts(normalize=True))
plt.bar(['Effective', 'Not Effective'], [len(df_panss_control_diff[df_panss_control_diff['Effective'] == True]), len(df_panss_control_diff[df_panss_control_diff['Effective'] == False])])
plt.title('Control Group')
# Out:
# True     135
# False     42
# Name: Effective, dtype: int64
#
# True     0.762712
# False    0.237288
# Name: Effective, dtype: float64
# Text(0.5, 1.0, 'Control Group')

# %%
# let's see every patient's PANSS_Total's trend over each visit
df_panss

df_panss[df_panss['PatientID'] == 10351]
# Out:
#       PatientID  VisitDay  PANSS_Total
# 2396      10351         0           93
# 2397      10351         9           90
# 2398      10351        16           81
# 2399      10351        23           84
# 2400      10351        37           84
# 2401      10351        51           83
# 2402      10351        53          112

# %%
df_panss[df_panss['PatientID'] == 10351].plot(x='VisitDay', y='PANSS_Total', kind='line')
# Out:
# <AxesSubplot: xlabel='VisitDay'>

# %%
# I like to see if PANSS_Total is decreased for three consecutive visits then we say it's effective, otherwise it's not effective.
df_panss['PatientID'].value_counts()
# Out:
# 10226    9
# 10284    9
# 10092    9
# 10095    9
# 10097    9
#         ..
# 10222    1
# 10305    1
# 10345    1
# 10151    1
# 10241    1
# Name: PatientID, Length: 159, dtype: int64

# %%
# let's see how many patients have three or more visits
df_panss['PatientID'].value_counts()[df_panss['PatientID'].value_counts() >= 3]
# Out:
# 10226    9
# 10284    9
# 10092    9
# 10095    9
# 10097    9
#         ..
# 10130    3
# 10129    3
# 10064    3
# 10197    3
# 10248    3
# Name: PatientID, Length: 131, dtype: int64

# %%
# let's see how many patients have three or more visits and their PANSS_Total is decreased for three consecutive visits
df_panss_effective = pd.DataFrame(columns=['PatientID', 'Effective'])

for patient_id in df_panss['PatientID'].value_counts()[df_panss['PatientID'].value_counts() >= 3].index:
    patient_panss = df_panss[df_panss['PatientID'] == patient_id]
    effective = False
    for i in range(len(patient_panss) - 2):
        if patient_panss.iloc[i]['PANSS_Total'] > patient_panss.iloc[i + 1]['PANSS_Total'] > patient_panss.iloc[i + 2]['PANSS_Total']:
            effective = True
            break
    df_panss_effective = df_panss_effective.append({'PatientID': patient_id, 'Effective': effective}, ignore_index=True)
    
df_panss_effective
# Out:
#     PatientID Effective
# 0       10226      True
# 1       10284      True
# 2       10092      True
# 3       10095      True
# 4       10097      True
# ..        ...       ...
# 126     10130     False
# 127     10129      True
# 128     10064     False
# 129     10197     False
# 130     10248      True
#
# [131 rows x 2 columns]

# %%
print(df_panss_effective['Effective'].value_counts(), '\n')
print(df_panss_effective['Effective'].value_counts(normalize=True))
plt.bar(['Effective', 'Not Effective'], [len(df_panss_effective[df_panss_effective['Effective'] == True]), len(df_panss_effective[df_panss_effective['Effective'] == False])])
plt.title('Treatment Group')
# Out:
# True     94
# False    37
# Name: Effective, dtype: int64
#
# True     0.717557
# False    0.282443
# Name: Effective, dtype: float64
# Text(0.5, 1.0, 'Treatment Group')

# %%
# let's do the same procedure for the control group
df_panss_control
# Out:
#       PatientID  VisitDay  PANSS_Total
# 0         10001         0          107
# 1         10001        11          109
# 2         10001        18           91
# 7         10002         0           85
# 8         10002         7           85
# ...         ...       ...          ...
# 2390      10350        20           76
# 2391      10350        34           70
# 2392      10350        49           69
# 2393      10350        61           67
# 2395      10350        89           64
#
# [894 rows x 3 columns]

# %%
df_panss_control['PatientID'].value_counts()
# Out:
# 10161    9
# 10059    9
# 10091    9
# 10266    9
# 10285    9
#         ..
# 10184    1
# 10066    1
# 10073    1
# 10314    1
# 10029    1
# Name: PatientID, Length: 177, dtype: int64

# %%
df_panss_control['PatientID'].value_counts()[df_panss_control['PatientID'].value_counts() >= 3]

df_panss_control_effective = pd.DataFrame(columns=['PatientID', 'Effective'])

for patient_id in df_panss_control['PatientID'].value_counts()[df_panss_control['PatientID'].value_counts() >= 3].index:
    patient_panss = df_panss_control[df_panss_control['PatientID'] == patient_id]
    effective = False
    for i in range(len(patient_panss) - 2):
        if patient_panss.iloc[i]['PANSS_Total'] > patient_panss.iloc[i + 1]['PANSS_Total'] > patient_panss.iloc[i + 2]['PANSS_Total']:
            effective = True
            break
    df_panss_control_effective = df_panss_control_effective.append({'PatientID': patient_id, 'Effective': effective}, ignore_index=True)
    
df_panss_control_effective
# Out:
#     PatientID Effective
# 0       10161      True
# 1       10059      True
# 2       10091     False
# 3       10266      True
# 4       10285      True
# ..        ...       ...
# 144     10045      True
# 145     10249     False
# 146     10250     False
# 147     10171     False
# 148     10258     False
#
# [149 rows x 2 columns]

# %%
print(df_panss_control_effective['Effective'].value_counts(), '\n')
print(df_panss_control_effective['Effective'].value_counts(normalize=True))
plt.bar(['Effective', 'Not Effective'], [len(df_panss_control_effective[df_panss_control_effective['Effective'] == True]), len(df_panss_control_effective[df_panss_control_effective['Effective'] == False])])
plt.title('Control Group')
# Out:
# True     104
# False     45
# Name: Effective, dtype: int64
#
# True     0.697987
# False    0.302013
# Name: Effective, dtype: float64
# Text(0.5, 1.0, 'Control Group')
